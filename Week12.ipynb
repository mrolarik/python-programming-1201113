# %% [markdown]
# **NumPy**
#
# `NumPy (Numerical Python)` เป็นไลบรารีที่ใช้จัดการ `อาร์เรย์ (Array)` และการคำนวณทางคณิตศาสตร์อย่างมีประสิทธิภาพใน Python

# %% [markdown]
# # 🔹 การติดตั้ง NumPy
#
# หากยังไม่มี `NumPy` สามารถติดตั้งได้โดยใช้คำสั่งนี้ใน Terminal หรือ Command Prompt:
#
# ```
# !pip install numpy
# ```

# %% [markdown]
# #🔹 การนำเข้า (Import) NumPy
#
# ```
# import numpy as np
# ```

# %% [markdown]
# #🔹 การสร้างอาร์เรย์ (Array)
#
# `NumPy` ใช้ `numpy.array()` เพื่อสร้างอาร์เรย์

# %% [markdown]
# ## 1. สร้างอาร์เรย์ 1 มิติ (1D Array)
#
# ```
# arr = np.array([1, 2, 3, 4, 5])
# print(arr)
# ```
#
# ผลลัพธ์
# ```
# [1 2 3 4 5]
# ```

# %% [markdown]
# ทดลองสร้างอาร์เรย์ 1 มิติ

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# ## 2. สร้างอาร์เรย์ 2 มิติ (2D Array)
# ```
# arr2d = np.array([[1, 2, 3], [4, 5, 6]])
# print(arr2d)
# ```
# ผลลัพธ์
# ```
# [[1 2 3]
#  [4 5 6]]
# ```

# %% [markdown]
# ทดลองสร้างอาร์เรย์ 2 มิติ จากตัวอย่างข้างต้น

# %%
#code here
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## 3. สร้างอาร์เรย์ 3 มิติ (3D Array)
# ```
# arr3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
# print(arr3d)
# ```
# ผลลัพธ์
# ```
# [[[1 2]
#   [3 4]]
#
#   [[5 6]
#    [7 8]]]
# ```

# %% [markdown]
# ทดลองสร้างอาร์เรย์ 3 มิติ จากตัวอย่างข้างต้น

# %%
#code here
import numpy as np
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %% [markdown]
# # 🔹 การสร้างอาร์เรย์พิเศษ

# %% [markdown]
# ##1. อาร์เรย์ที่มีค่าเป็น 0 `(zeros())`
# ```
# zeros_array = np.zeros((2, 3))  # สร้างอาร์เรย์ขนาด 2x3 ที่มีค่าเป็น 0
# print(zeros_array)
# ```
# ผลลัพธ์
#
# ```
# [[0. 0. 0.]
#  [0. 0. 0.]]
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# ## 2. อาร์เรย์ที่มีค่าเป็น 1 `(ones())`
# ```
# ones_array = np.ones((3, 3))  # สร้างอาร์เรย์ขนาด 3x3 ที่มีค่าเป็น 1
# print(ones_array)
# ```
# ผลลัพธ์
# ```
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %% [markdown]
# ## 3. อาร์เรย์ที่มีค่าตามลำดับ `(arange())`
#
# ```
# range_array = np.arange(1, 10, 2)  # เริ่มจาก 1 ถึง 9 โดยเพิ่มทีละ 2
# print(range_array)
# ```
# ผลลัพธ์
# ```
# [1 3 5 7 9]
# ```

# %%
#code here
# Out:
# [1 3 5 7 9]

# %% [markdown]
# ## 4. อาร์เรย์ที่มีค่ากระจายอย่างสม่ำเสมอ `(linspace())`
#
# ```
# linspace_array = np.linspace(0, 10, 5)  # สร้างค่า 5 ตัวจาก 0 ถึง 10
# print(linspace_array)
# ```
# ผลลัพธ์
# ```
# [  0.   2.5  5.   7.5 10. ]
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %% [markdown]
# #🔹 การเข้าถึงและเปลี่ยนค่าข้อมูลในอาร์เรย์

# %% [markdown]
# ## 1. การเข้าถึงค่าจากอาร์เรย์ 1 มิติ
#
# ```
# arr = np.array([10, 20, 30, 40])
# print(arr[2])
# ```
# ผลลัพธ์
# ```
# 30
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# 30

# %% [markdown]
# ## 2. การเข้าถึงค่าจากอาร์เรย์ 2 มิติ
#
# ```
# arr2d = np.array([[1, 2, 3], [4, 5, 6]])
# print(arr2d[1, 2])  # Output: 6 (แถวที่ 1 คอลัมน์ที่ 2)
# ```
# ผลลัพธ์
# ```
# 6
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# 6

# %% [markdown]
# ## 3. การเปลี่ยนค่าข้อมูล
#
# ```
# arr = np.array([10, 20, 30, 40])
#
# arr[2] = 99
# print(arr)
# ```
# ผลลัพธ์
# ```
# [10 20 99 40]
# ```

# %% [markdown]
# #🔹 การดำเนินการทางคณิตศาสตร์กับอาร์เรย์
#
# `NumPy` สามารถใช้สำหรับคำนวณเลขได้อย่างรวดเร็ว
#
# ```
# arr = np.array([1, 2, 3, 4])
#
# print(arr + 10)  # บวก 10 ทุกตัวในอาร์เรย์
# print(arr * 2)   # คูณ 2 ทุกตัวในอาร์เรย์
# print(arr / 2)   # หาร 2 ทุกตัวในอาร์เรย์
# print(arr ** 2)  # ยกกำลัง 2 ทุกตัวในอาร์เรย์
# ```
# ผลลัพธ์
# ```
# [11 12 13 14]
# [2 4 6 8]
# [0.5 1.  1.5 2. ]
# [ 1  4  9 16]
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# [11 12 13 14]
# [2 4 6 8]
# [0.5 1.  1.5 2. ]
# [ 1  4  9 16]

# %% [markdown]
# #🔹 การคำนวณเชิงสถิติ
# ```
# arr = np.array([10, 20, 30, 40, 50])
#
# print("ผลรวม:", np.sum(arr))  # ผลรวมของอาร์เรย์
# print("ค่าเฉลี่ย:", np.mean(arr))  # ค่าเฉลี่ย
# print("ค่ามากสุด:", np.max(arr))  # ค่ามากสุด
# print("ค่าน้อยสุด:", np.min(arr))  # ค่าน้อยสุด
# print("ค่ามัธยฐาน:", np.median(arr))  # ค่ามัธยฐาน
# print("ส่วนเบี่ยงเบนมาตรฐาน:", np.std(arr))  # ส่วนเบี่ยงเบนมาตรฐาน
# ```
# ผลลัพธ์
# ```
# ผลรวม: 150
# ค่าเฉลี่ย: 30.0
# ค่ามากสุด: 50
# ค่าน้อยสุด: 10
# ค่ามัธยฐาน: 30.0
# ส่วนเบี่ยงเบนมาตรฐาน: 14.142135623730951
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here

arr = np.array([10, 20, 30, 40, 50])

print("ผลรวม:", np.sum(arr))  # ผลรวมของอาร์เรย์
print("ค่าเฉลี่ย:", np.mean(arr))  # ค่าเฉลี่ย
print("ค่ามากสุด:", np.max(arr))  # ค่ามากสุด
print("ค่าน้อยสุด:", np.min(arr))  # ค่าน้อยสุด
print("ค่ามัธยฐาน:", np.median(arr))  # ค่ามัธยฐาน
print("ส่วนเบี่ยงเบนมาตรฐาน:", np.std(arr))  # ส่วนเบี่ยงเบนมาตรฐาน
# Out:
# ผลรวม: 150
# ค่าเฉลี่ย: 30.0
# ค่ามากสุด: 50
# ค่าน้อยสุด: 10
# ค่ามัธยฐาน: 30.0
# ส่วนเบี่ยงเบนมาตรฐาน: 14.142135623730951

# %% [markdown]
# #🔹 การใช้ NumPy ในฟังก์ชัน
#
# ```
# def calculate_statistics(arr):
#     print(f"ผลรวม: {np.sum(arr)}")
#     print(f"ค่าเฉลี่ย: {np.mean(arr)}")
#     print(f"ค่ามากสุด: {np.max(arr)}")
#     print(f"ค่าน้อยสุด: {np.min(arr)}")
#
# # ตัวอย่างการใช้ฟังก์ชัน
# data = np.array([5, 10, 15, 20, 25])
# calculate_statistics(data)
# ```
# ผลลัพธ์
# ```
# ผลรวม: 75
# ค่าเฉลี่ย: 15.0
# ค่ามากสุด: 25
# ค่าน้อยสุด: 5
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here
# Out:
# ผลรวม: 75
# ค่าเฉลี่ย: 15.0
# ค่ามากสุด: 25
# ค่าน้อยสุด: 5

# %% [markdown]
# #🔥 ตัวอย่างโปรแกรม: คำนวณค่า BMI โดยใช้ NumPy
#
# 📌 เงื่อนไขของโปรแกรม
# * รับ น้ำหนัก (kg) และ ส่วนสูง (m) เป็น NumPy Array
# * คำนวณค่า BMI โดยใช้สูตร
#
#  ![image.png](data:image/png;base64,...)
#
#
# * แสดงค่า BMI และสถานะน้ำหนักของแต่ละคน

# %% [markdown]
# 🎯 ตัวอย่างโปรแกรม
# ```
# import numpy as np
#
# # ข้อมูลน้ำหนัก (kg) และส่วนสูง (m) ของ 5 คน
# weights = np.array([55, 70, 60, 80, 95])  # น้ำหนัก
# heights = np.array([1.65, 1.75, 1.60, 1.80, 1.75])  # ส่วนสูง
#
# # คำนวณ BMI
# bmi = weights / (heights ** 2)
#
# # ฟังก์ชันกำหนดสถานะน้ำหนักตามค่า BMI
# def categorize_bmi(bmi_values):
#     categories = []
#     for value in bmi_values:
#         if value < 18.5:
#             categories.append("ผอม")
#         elif 18.5 <= value < 24.9:
#             categories.append("ปกติ")
#         elif 25 <= value < 29.9:
#             categories.append("น้ำหนักเกิน")
#         else:
#             categories.append("อ้วน")
#     return np.array(categories)
#
# # กำหนดหมวดหมู่ BMI
# bmi_categories = categorize_bmi(bmi)
#
# # แสดงผลลัพธ์
# for i in range(len(weights)):
#     print(f"บุคคล {i+1}: น้ำหนัก {weights[i]} kg, สูง {heights[i]} m, BMI: {bmi[i]:.2f}, สถานะ: {bmi_categories[i]}")
#
# ```

# %% [markdown]
# 🎯 ตัวอย่างผลลัพธ์
#
# ```
# บุคคล 1: น้ำหนัก 55 kg, สูง 1.65 m, BMI: 20.20, สถานะ: ปกติ
# บุคคล 2: น้ำหนัก 70 kg, สูง 1.75 m, BMI: 22.86, สถานะ: ปกติ
# บุคคล 3: น้ำหนัก 60 kg, สูง 1.60 m, BMI: 23.44, สถานะ: ปกติ
# บุคคล 4: น้ำหนัก 80 kg, สูง 1.80 m, BMI: 24.69, สถานะ: ปกติ
# บุคคล 5: น้ำหนัก 95 kg, สูง 1.75 m, BMI: 31.02, สถานะ: อ้วน
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมจากตัวอย่างข้างต้น

# %%
#code here

# %% [markdown]
# #📌 โจทย์: วิเคราะห์คะแนนสอบนักเรียนโดยใช้ `NumPy` และ `Function`
#
# จงเขียนโปรแกรมที่ใช้ NumPy และ Function เพื่อวิเคราะห์คะแนนสอบของนักเรียน โดยโปรแกรมต้องสามารถ:
#
# 1. รับค่าคะแนนสอบจากผู้ใช้เป็นอาร์เรย์ของ NumPy
# 2. คำนวณค่า เฉลี่ย (Mean), ค่ามัธยฐาน (Median), ค่าสูงสุด (Max), ค่าต่ำสุด (Min), และ ส่วนเบี่ยงเบนมาตรฐาน (Standard Deviation)
# 3. แสดงเกรดของนักเรียนแต่ละคนตามเงื่อนไขต่อไปนี้:
#
# * 90 - 100 → A
# * 80 - 89 → B
# * 70 - 79 → C
# * 60 - 69 → D
# * < 60 → F
#
#
# 🎯 ตัวอย่างผลลัพธ์ของโปรแกรม
# ```
# ป้อนคะแนนสอบของนักเรียน (คั่นด้วยช่องว่าง): 85 92 78 65 59 90 88 73 45 100
#
# ===== ผลการวิเคราะห์คะแนน =====
# ค่าเฉลี่ย (Mean): 77.50
# ค่ามัธยฐาน (Median): 79.00
# ค่าสูงสุด (Max): 100.0
# ค่าต่ำสุด (Min): 45.0
# ส่วนเบี่ยงเบนมาตรฐาน (Standard Deviation): 17.20
#
# ===== คะแนนและเกรดของนักเรียน =====
# นักเรียน 1: คะแนน 85.0, เกรด B
# นักเรียน 2: คะแนน 92.0, เกรด A
# นักเรียน 3: คะแนน 78.0, เกรด C
# นักเรียน 4: คะแนน 65.0, เกรด D
# นักเรียน 5: คะแนน 59.0, เกรด F
# นักเรียน 6: คะแนน 90.0, เกรด A
# นักเรียน 7: คะแนน 88.0, เกรด B
# นักเรียน 8: คะแนน 73.0, เกรด C
# นักเรียน 9: คะแนน 45.0, เกรด F
# นักเรียน 10: คะแนน 100.0, เกรด A
# ```

# %% [markdown]
# **ตัวอย่างโปรแกรม** การรับคะแนนสอบของนักเรียน
#
# ```
# def get_scores():
#   scores = input("ป้อนคะแนนสอบของนักเรียน (คั่นด้วยช่องว่าง): ")
#   scores_list = list(map(float, scores.split()))
#   return np.array(scores_list)
#
# print(get_scores())
# ```
#
# ผลลัพธ์
# ```
# ป้อนคะแนนสอบของนักเรียน (คั่นด้วยช่องว่าง): 3 4 5 6 7 8
# [3. 4. 5. 6. 7. 8.]
# ```

# %%
#code here

# %% [markdown]
# #📌 โจทย์: ระบบจัดการข้อมูลสินค้าในคลังสินค้าโดยใช้ NumPy
#
# จงเขียนโปรแกรมที่ใช้ NumPy ในการจัดการข้อมูลสินค้าในคลัง โดยโปรแกรมต้องสามารถ:
# 1. เพิ่มสินค้าใหม่ ลงในอาร์เรย์ (สินค้า: ชื่อสินค้า, จำนวน, ราคา)
# 2. แสดงรายการสินค้าทั้งหมด
# 3. ค้นหาสินค้าตามชื่อ
# 4. อัปเดตจำนวนสินค้าหรือราคาสินค้า
# 5. คำนวณมูลค่ารวมของสินค้าทั้งหมด
# 6. ออกจากโปรแกรม
#
# 📌 ข้อกำหนด
# * ใช้ NumPy array จัดเก็บข้อมูลสินค้า
# * ใช้ Function เพื่อแยกส่วนการทำงาน

# %% [markdown]
# 🎯 ตัวอย่างผลลัพธ์ของโปรแกรม
#
# ```
# ===== ระบบจัดการคลังสินค้า =====
# 1. เพิ่มสินค้าใหม่
# 2. แสดงรายการสินค้า
# 3. ค้นหาสินค้า
# 4. อัปเดตจำนวนหรือราคาสินค้า
# 5. คำนวณมูลค่ารวมของสินค้าทั้งหมด
# 6. ออกจากโปรแกรม
# เลือกเมนู: 1
# ป้อนชื่อสินค้า: Laptop
# ป้อนจำนวนสินค้า: 10
# ป้อนราคาสินค้าต่อหน่วย: 25000
# ✅ เพิ่มสินค้า Laptop เรียบร้อย!
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 1
# ป้อนชื่อสินค้า: Smartphone
# ป้อนจำนวนสินค้า: 20
# ป้อนราคาสินค้าต่อหน่วย: 15000
# ✅ เพิ่มสินค้า Smartphone เรียบร้อย!
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 2
#
# ===== รายการสินค้า =====
# 1. ชื่อ: Laptop, จำนวน: 10, ราคา: 25000.0 บาท
# 2. ชื่อ: Smartphone, จำนวน: 20, ราคา: 15000.0 บาท
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 3
# ป้อนชื่อสินค้าที่ต้องการค้นหา: Laptop
#
# 🔍 ผลการค้นหา:
# ชื่อ: Laptop, จำนวน: 10, ราคา: 25000.0 บาท
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 4
# ป้อนชื่อสินค้าที่ต้องการอัปเดต: Laptop
# 🔄 สินค้าปัจจุบัน: ['Laptop' 10 25000.0]
# เลือกอัปเดต (1: จำนวนสินค้า, 2: ราคา): 1
# ป้อนจำนวนสินค้าใหม่: 15
# ✅ อัปเดตจำนวนสินค้าของ Laptop เป็น 15 เรียบร้อย!
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 5
#
# 💰 มูลค่ารวมของสินค้าทั้งหมด: 525000.00 บาท
#
# ===== ระบบจัดการคลังสินค้า =====
# เลือกเมนู: 6
# 🚪 ออกจากโปรแกรม...
#
# ```

# %%
#code here
import numpy as np

# สร้างอาร์เรย์เก็บข้อมูลสินค้า (เริ่มต้นว่างเปล่า)
products = np.empty((0, 3), dtype=object)  # เก็บสินค้าในรูปแบบ: [ชื่อสินค้า, จำนวน, ราคา]

# ฟังก์ชันแสดงเมนู
def show_menu():
    print("\n===== ระบบจัดการคลังสินค้า =====")
    print("1. เพิ่มสินค้าใหม่")
    print("2. แสดงรายการสินค้า")
    print("3. ค้นหาสินค้า")
    print("4. อัปเดตจำนวนหรือราคาสินค้า")
    print("5. คำนวณมูลค่ารวมของสินค้าทั้งหมด")
    print("6. ออกจากโปรแกรม")


# ฟังก์ชันเพิ่มสินค้าใหม่
def add_product():
    global products
    name = input("ป้อนชื่อสินค้า: ")
    quantity = int(input("ป้อนจำนวนสินค้า: "))
    price = float(input("ป้อนราคาสินค้าต่อหน่วย: "))

    new_product = np.array([[name, quantity, price]], dtype=object)
    products = np.vstack([products, new_product])  # เพิ่มข้อมูลลงในอาร์เรย์

    print(f"✅ เพิ่มสินค้า {name} เรียบร้อย!")

#เขียนโปรแกรมต่อให้สมบูรณ์
