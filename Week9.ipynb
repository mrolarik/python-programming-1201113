# %% [markdown]
# **ทบทวนการเขียนโปแกรม**

# %% [markdown]
# # **ข้อที่ 1: การใช้ if-else หรือ nested-if**
# **โจทย์:**.
#
# เขียนโปรแกรมรับคะแนนสอบจากผู้ใช้ (ค่าคะแนนอยู่ระหว่าง 0-100) แล้วแสดงผลเกรดตามเกณฑ์ดังนี้
# * คะแนน 80-100 ได้เกรด A
# * คะแนน 70-79 ได้เกรด B
# * คะแนน 60-69 ได้เกรด C
# * คะแนน 50-59 ได้เกรด D
# * คะแนนต่ำกว่า 50 ได้เกรด F
# * หากผู้ใช้ป้อนค่านอกช่วง 0-100 ให้แจ้งเตือนว่า "คะแนนไม่ถูกต้อง"

# %%
#code here

# %% [markdown]
# # ข้อที่ 2: การใช้ while-loop และ for-loop
# **โจทย์:**
#
# เขียนโปรแกรมให้ผู้ใช้ป้อนตัวเลขไปเรื่อย ๆ จนกว่าผู้ใช้จะป้อน 0 จากนั้นให้แสดงผลรวมของตัวเลขทั้งหมดที่ป้อนมา (ไม่รวม 0)

# %%
#code here

# %% [markdown]
# # ช้อที่ 3: การใช้ 2D List และการหาค่าสูงสุด และค่าต่ำสุดใน List
#
# **โจทย์:**
#
# เขียนโปรแกรมเพื่อหาค่าสูงสุด และต่ำสุดภายใน 2D List ต่อไปนี้
#
# ```
# num_list = [[4, 5, 6],
#             [7, 8, 9],
#             [10, 2, 5]]
# ```
#
# ผลลัพธ์ที่ได้
# ```
# ค่าต่ำสุดคือ: 2
# ค่าสูงสุดคือ: 10
# ```

# %%
#code here

# %% [markdown]
# #ข้อที่ 4: การเข้าถึงข้อมูลใน List
#
# ให้สร้าง List ดังต่อไปนี้
# ```
# num_list = [[4, 5, 6],
#             [7, 8, 9],
#             [10, 2, 5]]
# ```
#
# จาก List ข้างต้น ให้เขียนโปรแกรมตามโจทย์ต่อไปนี้

# %% [markdown]
# ##ข้อ 4.1: เขียนโปรแกรมเพื่อแสดงข้อมูลเฉพาะ
# ```
# 4, 5, 6
# ```

# %%
#code here
# Out:
# 6

# %% [markdown]
# เขียนโปรแกรมเพื่อแสดงอินเด็กซ์ของข้อมูลใน List
# ```
# num_list = [[4, 5, 6],
#             [7, 8, 9],
#             [10, 2, 5]]
# ```
# ผลลัพธ์ที่ต้องการ
# ```
# 0,0 0,1 0,2
# 1,0 1,1 1,2
# 2,0 2,1 2,2
# ```

# %%
#code here

# %% [markdown]
# ##ข้อ 4.2: เขียนโปรแกรมเพื่อแสดงข้อมูลเฉพาะเลขคู่
# ```
# 4 6 8 10 2
# ```
#
# **trick**
# ให้ใช้ moderation (%) เช่น
# ```
# 10 % 2
# ```
# ผลลัพธ์ที่ได้คือ
# ```
# 0
# ```
# หากหารด้วย 2 ลงตัว ผลลัพธ์จะมีค่าเป็น 0 นั่นแหมายถึง เลขคู่ และหากหารด้วย 2 ไม่ลงตัว ตัวเลขนั้นมีค่าเป็น เลขคี่

# %%
#code here

# %% [markdown]
# ## เขียนโปรแกรมเพื่อแสดงอินเด็กซ์ของเลขคู่ จากลิสต์ต่อไปนี้
# ```
# num_list = [[4, 5, 6],
#             [7, 8, 9],
#             [10, 2, 5]]
# ```
# ผลลัพธ์ที่ต้องการ
# ```
# 0,0 0,2 1,1 2,0 2,1
# ```

# %%
#code here

# %% [markdown]
# ## ข้อ 4.3: เขียนโปรแกรมเพื่อแสดงข้อมูลเฉพาะเลขคี่
# ```
# 5 7 9 5
# ```

# %%
#code here

# %% [markdown]
# # ข้อที่ 5: การใช้ 2D List
# **โจทย์:**
#
# เขียนโปรแกรมสร้างเมทริกซ์ (Matrix หรือ List) ขนาด 3x3 ที่ผู้ใช้ป้อนค่าทั้งหมด จากนั้นให้แสดงค่าที่ผู้ใช้ป้อนในรูปแบบตาราง
#
# *ตัวอย่างโปรแกรมแสดงดังนี้*
#
# ```
# กรุณาป้อนค่าของเมทริกซ์ 3x3
#
# ป้อนค่าที่ตำแหน่ง 0,0: 1
# ป้อนค่าที่ตำแหน่ง 0,1: 2
# ป้อนค่าที่ตำแหน่ง 0,2: 3
# ป้อนค่าที่ตำแหน่ง 1,0: 4
# ป้อนค่าที่ตำแหน่ง 1,1: 5
# ป้อนค่าที่ตำแหน่ง 1,2: 6
# ป้อนค่าที่ตำแหน่ง 2,0: 7
# ป้อนค่าที่ตำแหน่ง 2,1: 8
# ป้อนค่าที่ตำแหน่ง 2,2: 9
#
# เมทริกซ์ที่คุณป้อนคือ:
# 1 2 3
# 4 5 6
# 7 8 9
#
# ```

# %%
#code here

# %% [markdown]
# # ข้อที่ 6: การใช้ 2D List และการสร้างเมนู
# **โจทย์:**
#
# เขียนโปรแกรมที่ให้ผู้ใช้จัดการเมทริกซ์ 3x3 โดยมีเมนูให้เลือกดังนี้
# ```
# 1 ป้อนค่าลงเมทริกซ์
# 2 แสดงค่าของเมทริกซ์
# 3 หาค่าสูงที่สุดในเมทริกซ์
# 4 หยุดโปรแกรม
# เลือกเมนูที่ต้องการ:
# ```

# %%
#code here
