# %% [markdown]
# #Lab 2 : Area Calculation

# %% [markdown]
# **การคำนวณหาพื้นที่ (Area)**
#
# สิ่งที่ต้องคำนึงถึงในการเขียนโปรแกรมคือ
#
# *   การกำหนดค่าตัวแปร (Variable)
# *   การกำหนด Input, Process, Output

# %% [markdown]
# ให้นิสิตคำนวณพื้นที่สามเหลี่ยม (Triangle) ต่อไปนี้
#
# *   สามเหลี่ยมมีความสูง 20 เมตร และความกว้าง 10 เมตร อยากทราบว่าสามเหลี่ยมมีพื้นที่กี่ตารางเมตร

# %%
#Input
high = 20
width = 10

#Process
area = (1/2) * high * width

#Output
print("Area of Triangle is ", area, "square meter")
# Out:
# Area of Triangle is  100.0 Square meter

# %% [markdown]
# **โจทย์ 2**
# สามเหลี่ยมมีความกว้าง 155 เซนติเมตร และมีความสูง 3.3 เมตร อยากทราบว่าสามเหลี่ยมมีพื้นที่กี่ตารางเมตร

# %%
#code here

# %% [markdown]
# **โจทย์ 3**
# สามเหลี่ยมมีความสูง 140 เซนติเมตร และมีความกว้าง 120 เซนติเมตร อยากทราบว่าสามเหลี่ยมมีพื้นที่กี่ตารางเมตร

# %%
#code here

# %% [markdown]
# **โจทย์ 4**
# นิสิตมีที่ดินอยู่สองแปลง แปลงแรก มีความกว้าง 200 เมตร มีความยาว 450 เมตร และแปลงที่สองที่ดินเป็นรูปร่างสามเหลี่ยม ที่มีความกว้าง 1500 เมตร และความความสูง 50000 เซนติเมตร
#
# อยากทราบว่านิสิตคนนี้มีที่ดินรวมกันจำนวนกี่ตารางเมตร

# %%
#code here

# %% [markdown]
# **โจทย์ 5**
# มีวงกลมอยู่หนึ่งวง โดยวงกลมนั้นมีรัศมี (Radius) คือ 35 เซนติเมตร
#
# อยากทราบว่าวงกลมวงนั้นมีพื้นที่เท่าไหร่

# %%
#code here

# %% [markdown]
# **โจทย์ 6**
# หากวงกลมมีเส้นผ่านศูนย์กลาง (diameter) 27.5 เมตร
#
# อยากทราบว่าวงกลมนั้นมีรัศมีกี่เซนติเมตร

# %%
#code here

# %% [markdown]
# **โจทย์ 7**
# ตึกมีรูปร่างเป็นทรงกระบอก โดยตึกนั้นมีเส้นผ่านศูนย์กลาง 75 เมตร อยากทราบว่าหากนิสิตต้องการเดินรอบตึก (เส้นรอบวง circumference) จะต้องเดินระยะทางกี่เมตร

# %%
#code here

# %% [markdown]
# #Lab 3: If-else

# %% [markdown]
# **If-else (ถ้า-แล้ว)**
#
#
#
#
# ```
# triangle = 45
# circle = 30
#
# if(triangle > circle):        #<---เงื่อนไข (Condition)
#   print(“triangle bigger than circle”)
# else:
#   print(“Circle bigger than triangle”)
#
#  ```

# %% [markdown]
# ```
# if(triangle > circle):
# ```
#
# เงื่อนไขจะมีเพียง 2 ค่าเท่านั้นคือ **True** และ **False**
#
# *   สัญลักษณ์ที่จะใช้เปรียบเทียบในเงื่อนไข เช่น
# *   ` >, >=, <, <=, !=, == `

# %% [markdown]
# **โจทย์ 8**
#
# นาย ก ปลูกบ้านอยู่บนที่ดินที่เป็นพื้นที่สามเหลี่ยมที่มีขนาด ความสูง 68 เมตร กว้าง 45 เมตร
#
# นาย ข ปลูกบ้านอยู่บนที่ดินที่เป็นพื้นที่วงกลมที่มีเส้นผ่านศูนย์กลาง 68 เมตร
#
# อยากทราบว่าที่ดินของนาย ก หรือนาย ข ใหญ่กว่ากัน

# %%
#code here
