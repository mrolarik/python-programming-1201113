# %% [markdown]
# # ฟังก์ชัน (Function)
#
# 📌 **ฟังก์ชันใน Python คืออะไร?**
# ฟังก์ชัน (Function) คือกลุ่มของคำสั่งที่ทำงานร่วมกันเพื่อทำสิ่งใดสิ่งหนึ่งให้สำเร็จ โดยสามารถเรียกใช้ซ้ำได้ในโปรแกรม ช่วยให้โค้ดอ่านง่ายและลดการทำงานที่ซ้ำซ้อน

# %% [markdown]
# #1. การสร้างฟังก์ชันใน Python
#
# ใน Python สามารถสร้างฟังก์ชันได้โดยใช้คำสั่ง `def` ตามด้วยชื่อฟังก์ชันและวงเล็บ ()
#
# ```
# def hello():
#   print("สวัสดี Python!")
# ```
#
# 📌 การเรียกใช้ฟังก์ชัน
# ```
# hello()
# ```
#
# 📌 Output
# ```
# สวัสดี Python!
# ```

# %% [markdown]
# ทดลองเขียนฟังก์ชัน `hello` และเรียกใช้ตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# สวัสดี Python!

# %% [markdown]
# #2. ฟังก์ชันที่มีพารามิเตอร์
#
# **พารามิเตอร์ (Parameter)** คือค่าที่สามารถส่งให้ฟังก์ชันเพื่อให้ฟังก์ชันนำไปประมวลผลข้อมูล
#
# ```
# def greet(name):
#   print(f"สวัสดี {name}!")
# ```
#
# 📌 การเรียกใช้ฟังก์ชัน
# ```
# greet("Alice")
# ```
#
# 📌 ผลลัพธ์
# ```
# สวัสดี Alice!
# ```

# %% [markdown]
# ทดลองเขียนฟังก์ชัน `greet` และเรียกใช้ตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# สวัสดี Alice!

# %% [markdown]
# #3. ฟังก์ชันที่มีค่าเริ่มต้นของพารามิเตอร์
#
# หากไม่ส่งค่าให้พารามิเตอร์ จะใช้ค่าที่กำหนดไว้เป็นค่าเริ่มต้น
# ```
# def greet(name="Python"):
#   print(f"สวัสดี {name}!")
# ```
# 📌 การเรียกใช้ฟังก์ชัน
# ```
# greet()  # Output: สวัสดี Python!
# greet("Alice")  # Output: สวัสดี Alice!
# ```
#
# 📌 ผลลัพธ์
# ```
# Python!
# สวัสดี Alice!
# ```

# %% [markdown]
# ทดลองเขียนฟังก์ชัน `greet` และเรียกใช้ตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# สวัสดี Python!
# สวัสดี Alice!

# %% [markdown]
# #4. ฟังก์ชันที่คืนค่ากลับ (Return Value)
#
# ในบางกรณี ผู้เขียนโปรแกรมอาจจะมีความต้องการให้ฟังก์ชันส่งค่ากลับคืนมาเพื่อนำไปใช้ประโยชน์ต่อ โดยสามารถใช้คำสั่ง `return`
#
# ```
# def add(a, b):
#   return a + b
# ```
#
# 📌 การเรียกใช้ฟังก์ชัน
# ```
# result = add(5, 3)
# print(result)
# ```
#
# 📌 ผลลัพธ์
# ```
# 8
# ```

# %% [markdown]
# ทดลองเขียนฟังก์ชัน `add` และเรียกใช้ตามตัวอย่างข้างต้น และทดลองส่งค่าพารามิเตอร์ที่แตกต่างกัน เช่น
#
# *   1, 2
# *   -1, -2
# *   5, 9
#
# ผลลัพธ์ที่ได้คืออะไร

# %%
#code here
# Out:
# 8

# %% [markdown]
# #5. ฟังก์ชันที่มีหลายพารามิเตอร์แบบไม่จำกัด
#
# หากไม่รู้ว่าฟังก์ชันสามารถรับพารามิเตอร์ได้กี่ค่า สามารถใช้ `*args` เพื่อรับค่าหลายค่าในรูปแบบของ `tuple`
#
# ```
# def add_numbers(*numbers):
#   return sum(numbers)
# ```
# 📌 การเรียกใช้ฟังก์ชัน
# ```
# result = add_number(1, 2, 3, 4, 5)
# print(result)
#
# #or
#
# print(add_numbers(1, 2, 3, 4, 5))
# ```
# 📌 ผลลัพธ์
# ```
# 15
#
# 15
# ```

# %% [markdown]
# ทดลองเขียนฟังก์ชัน `add_number` และเรียกใช้ตามตัวอย่างข้างต้น และทดลองส่งค่าพารามิเตอร์ที่แตกต่างกัน เช่น
# * (1, 2)
# * (-1, -2)
# * (1, 3, 5, 7, 9)
# ผลลัพธ์ที่ได้คืออะไร

# %%
#code here
# Out:
# 15
# 3
# -3
# 25

# %% [markdown]
# #Tuple (ทูเพิล)
#
# **Tuple** เป็นโครงสร้างข้อมูลที่คล้ายกับ `List` แต่ไม่สามารถเปลี่ยนแปลงค่าได้ (Immutable) เหมาะกับการเก็บข้อมูลที่ไม่ต้องการให้ถูกแก้ไข
#
# 📌 สร้าง Tuple
# ```
# fruits = ("apple", "banana", "cherry")
# print(fruits)
# ```
#
# 📌 ผลลัพธ์
# ```
# ('apple', 'banana', 'cherry')
# ```

# %% [markdown]
# ##1. การเข้าถึงข้อมูลใน Tuple
#
# ```
# fruits = ("apple", "banana", "cherry")
#
# print(fruits[0])  # Output: apple
# print(fruits[1])  # Output: banana
# print(fruits[-1])  # Output: cherry (เข้าถึงจากท้ายสุด)
# ```
#
# 📌 ผลลัพธ์
# ```
# apple
# banana
# cherry
# ```

# %% [markdown]
# ##2. การวนลูปอ่านค่าจาก Tuple
# ```
# fruits = ("apple", "banana", "cherry")
#
# for fruit in fruits:
#   print(fruit)
# ```
#
# 📌 ผลลัพธ์
# ```
# apple
# banana
# cherry
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมเพื่อแสดงข้อมูลจาก Tuple ดังตัวอย่างข้างต้น

# %%
#code here
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ##3. ตรวจสอบค่าที่อยู่ใน Tuple
#
# ```
# fruits = ("apple", "banana", "cherry")
#
# if "banana" in fruits:
#   print("มี banana อยู่ใน Tuple")
# ```
#
# 📌 ผลลัพธ์
# ```
# มี banana อยู่ใน Tuple
# ```

# %% [markdown]
# ##4. นับจำนวนครั้งที่ค่าปรากฏใน Tuple
#
# ```
# fruits = ("apple", "banana", "cherry")
#
# print(fruits.count("apple"))
# ```
#
# 📌 ผลลัพธ์
# ```
# apple
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# 1

# %% [markdown]
# ทดลองเขียนโปรแกรมเพื่อนับจำนวนครั้งที่ตัวเลข 1 ปรากฎใน Tuple
#
# ```
# numbers = (1, 1, 1, 2, 3, 4, 1, 2, 1)
# ```
#
# 📌 ผลลัพธ์
# ```
# 5
# ```

# %%
#code here
# Out:
# 5

# %% [markdown]
# ##5. ค้นหาตำแหน่งของค่าภายใน Tuple
#
# ```
# numbers = (10, 20, 30, 40, 50)
#
# print(numbers.index(30))
# ```
#
# 📌 ผลลัพธ์
# ```
# 2
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมตามตัวอย่างข้างต้น และเพิ่มเติมคือ ต้องการหาตำแหน่ง (Index) ของค่า 50 โดยผลลัพธ์ของโปรแกรมแสดงดังนี้
#
# 📌 ผลลัพธ์
# ```
# Index of 30 is 2
# Index of 50 is 4
# ```

# %%
#code here
numbers = (10, 20, 30, 40, 50)
# Out:
# Index of 30 is 2
# Index of 50 is 4

# %% [markdown]
# # ตัวอย่างการเขียนโปรแกรมร่วมกันระหว่าง `ฟังก์ชัน (Function)` ร่วมกับ `ทูเพิล (Tuple)`

# %% [markdown]
# ##ตัวอย่างที่ 1 การใช้ Tuple กับการ Return หลายค่า
#
# โดยฟังก์ชันสามารถคืนค่าออกมาเป็น Tuple ได้
#
# ```
# def get_coordinates():
#   return (10.5, 20.7)
# ```
# 📌 เรียกใช้ฟังก์ชัน และแสดงผลลัพธ์
# ```
# x, y = get_coordinates()
# print(f"x: {x}, y: {y}")
# ```
# 📌 ผลลัพธ์
#
# ```
# x: 10.5, y: 20.7
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# x: 10.5, y: 20.7

# %% [markdown]
# ## ตัวอย่างที่ 2: ใช้ Tuple เป็นค่าที่คืนจากฟังก์ชัน
#
# สามารถใช้ Tuple เพื่อคืนค่าหลายค่าพร้อมกันจากฟังก์ชันได้
#
# ```
# def get_student_info():
#   name = "Alice"
#   age = 20
#   grade = "A"
#   return (name, age, grade)  # คืนค่าเป็น Tuple
# ```
#
# 📌 เรียกใช้ฟังก์ชันและรับค่าที่คืนกลับมา
# ```
# student = get_student_info()
#
# print(student)
# ```
# 📌 ผลลัพธ์
# ```
# ('Alice', 20, 'A')
# ```
#
# 📌 การแยกค่าจาก Tuple
# ```
# name, age, grade = get_student_info()
#
# print(f"ชื่อ: {name}, อายุ: {age}, เกรด: {grade}")
# ```
# 📌 ผลลัพธ์
# ```
# ชื่อ: Alice, อายุ: 20, เกรด: A
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# ('Alice', 20, 'A')
# ชื่อ: Alice, อายุ: 20, เกรด: A

# %% [markdown]
# ## ตัวอย่างที่ 3: ใช้ Tuple เป็นพารามิเตอร์ของฟังก์ชัน
#
# สามารถส่ง Tuple เข้าไปในฟังก์ชันเพื่อประมวลผลข้อมูลได้
#
# ```
# def calculate_area_and_perimeter(dimensions):
#   length, width = dimensions  # ดึงค่าจาก Tuple
#   area = length * width
#   perimeter = 2 * (length + width)
#   return (area, perimeter)  # คืนค่าเป็น Tuple
# ```
#
# ```
# # ส่ง Tuple เป็นอาร์กิวเมนต์ให้ฟังก์ชัน
# rectangle = (10, 5)
#
# #เรียกใช้ฟังก์ชัน
# area, perimeter = calculate_area_and_perimeter(rectangle)
#
# #แสดงผลลัพธ์
# print(f"พื้นที่: {area}, เส้นรอบรูป: {perimeter}")
# ```
#
# 📌 ผลลัพธ์
# ```
# # Output: พื้นที่: 50, เส้นรอบรูป: 30
# ```

# %% [markdown]
# ทดลองเขียนโปรแกรมตามตัวอย่างข้างต้น

# %%
#code here
# Out:
# พื้นที่: 50, เส้นรอบรูป: 30

# %% [markdown]
# # โจทย์ เขียนโปรแกรมจัดการรายชื่อหนังสือ
#
# 📌 โจทย์
# เขียนโปรแกรม จัดการรายชื่อหนังสือ โดยมีเมนูให้เลือกดังนี้
# 1. เพิ่มหนังสือลงในรายการ
# 2. แสดงรายการหนังสือทั้งหมด
# 3. ค้นหาหนังสือจากชื่อ
# 4. ลบหนังสือออกจากรายการ
# 5. ออกจากโปรแกรม
#
# 📌 คำแนะนำ
# 1. ใช้ `List` เพื่อเก็บรายชื่อหนังสือ
# 2. ใช้ `Function` เพื่อแยกการทำงานแต่ละส่วน
# 3. ใช้ `Loop` ในเมนูหลักเพื่อให้ผู้ใช้เลือกทำงานซ้ำได้จนกว่าจะออกจากโปรแกรม
#
# 📌 ตัวอย่างการทำงานของโปรแกรม
# ```
# ===== เมนูจัดการหนังสือ =====
# 1. เพิ่มหนังสือ
# 2. แสดงรายการหนังสือ
# 3. ค้นหาหนังสือ
# 4. ลบหนังสือ
# 5. ออกจากโปรแกรม
# เลือกเมนู: 1
# ป้อนชื่อหนังสือ: Python for Beginners
# เพิ่มหนังสือเรียบร้อย!
#
# ===== เมนูจัดการหนังสือ =====
# 1. เพิ่มหนังสือ
# 2. แสดงรายการหนังสือ
# 3. ค้นหาหนังสือ
# 4. ลบหนังสือ
# 5. ออกจากโปรแกรม
# เลือกเมนู: 2
# รายการหนังสือ:
# 1. Python for Beginners
# ```

# %% [markdown]
# **เพิ่มเติม**

# %% [markdown]
# ตัวอย่าง การเริ่มต้นเขียนฟังก์ชัน
#
# ```
# # ฟังก์ชันแสดงเมนู
# def show_menu():
#     print("\n===== เมนูจัดการหนังสือ =====")
#     print("1. เพิ่มหนังสือ")
#     print("2. แสดงรายการหนังสือ")
#     print("3. ค้นหาหนังสือ")
#     print("4. ลบหนังสือ")
#     print("5. ออกจากโปรแกรม")
# ```
#
# ```
# while(True):
#   show_menu()
#   choice = int(input("เลือกเมนู: "))
#
#   if(choice == 1):
#     #เรียกใช้ฟังก์ชัน `เพิ่มหนังสือ`
#   elif(choice == 2
#     # เรียกใช้ฟังก์ชัน `แสดงรายการหนังสือ`
#
#
#
#
#   else:
#     print("กรุณาเลือกเมนูที่ถูกต้อง!")
# ```

# %% [markdown]
# ตัวอย่างการลบข้อมูลออกจากลิสต์
#
# 1. ใช้ `remove()` เพื่อลบค่าตามชื่อ
#
# 📌 `remove(value)` ใช้เพื่อลบค่าที่ตรงกับที่ระบุ (ถ้ามีค่าซ้ำกันจะลบตัวแรกที่พบ)
#
# ```
# fruits = ["apple", "banana", "cherry", "banana"]
# fruits.remove("banana")
# print(fruits)  # Output: ['apple', 'cherry', 'banana']
# ```
#
# 2. ใช้ pop() เพื่อลบค่าตามตำแหน่ง (Index)
#
# 📌 `pop(index)` ใช้ลบค่าตามลำดับ index ที่ระบุ (เริ่มจาก 0)
# * ถ้าไม่ระบุ index จะลบตัวสุดท้าย (`pop()`)
#
# ```
# fruits = ["apple", "banana", "cherry"]
# fruits.pop(1)  # ลบค่า index 1 ('banana')
# print(fruits)  # Output: ['apple', 'cherry']
#
# # ลบตัวสุดท้าย
# fruits.pop()
# print(fruits)  # Output: ['apple']
# ```

# %% [markdown]
# ตัวอย่าง การค้นหาข้อมูลในลิสต์
#
# * ใช้ `in` เพื่อตรวจสอบว่าค่ามีอยู่ใน List หรือไม่
#
# ```
# fruits = ["apple", "banana", "cherry"]
#
# if("banana" in fruits):
#     print("พบ banana ในรายการ!")
# else:
#     print("ไม่พบ banana")
#
# ```
#
# ผลลัพธ์
# ```
# พบ banana ในรายการ!
# ```

# %% [markdown]
# **เริ่มต้นเขียนโปรแกรมการจัดการรายชื่อหนังสือ**

# %% [markdown]
# **ฟังก์ชันที่ควรปรากฎในโปรแกรมได้แก่**
# * `def show_menu():`
# * `def add_book():`
# * `def show_books():`
# * `def search_book():`
# * `def remove_book():`

# %%
#code here

# สร้างตัวแปรเก็บรายการหนังสือ
book_list = []

# ฟังก์ชันแสดงเมนู
def show_menu():
  print("\n===== เมนูจัดการหนังสือ =====")
  print("1. เพิ่มหนังสือ")
  print("2. แสดงรายการหนังสือ")
  print("3. ค้นหาหนังสือ")
  print("4. ลบหนังสือ")
  print("5. ออกจากโปรแกรม")

# %% [markdown]
# # โจทย์ โปรแกรมคำนวณ BMI
#
# 📌 โปรแกรมคำนวณ BMI และเก็บข้อมูลใน List
# โปรแกรมนี้จะ
# ✅ รับค่าน้ำหนัก (kg) และส่วนสูง (m) จากผู้ใช้
# ✅ คำนวณค่าดัชนีมวลกาย (BMI)
# ✅ เก็บข้อมูลแต่ละคนไว้ใน List
# ✅ แสดงรายการ BMI ที่คำนวณได้ทั้งหมด
#
# 🎯 ตัวอย่างผลลัพธ์ของโปรแกรม
# ```
# ===== เมนูคำนวณ BMI =====
# 1. เพิ่มข้อมูล BMI
# 2. แสดงรายการ BMI
# 3. ออกจากโปรแกรม
# เลือกเมนู: 1
# ป้อนชื่อ: Alice
# ป้อนน้ำหนัก (kg): 55
# ป้อนส่วนสูง (m): 1.65
# Alice มีค่า BMI: 20.2
#
# ===== เมนูคำนวณ BMI =====
# 1. เพิ่มข้อมูล BMI
# 2. แสดงรายการ BMI
# 3. ออกจากโปรแกรม
# เลือกเมนู: 2
#
# ===== รายการ BMI =====
# ชื่อ: Alice, น้ำหนัก: 55 kg, สูง: 1.65 m, BMI: 20.2
# ```

# %% [markdown]
# # โจทย์ โปรแกรมคำนวณ BMI พร้อมแสดงเกณฑ์ความอ้วน
#
# จากโจทย์คำนวณค่า BMI ข้างต้น ให้นิสิตเพิ่มเติมโปรแกรมให้สมบูรณ์ ดังนี้
#
# * เพิ่มเติมให้โปรแกรมสามารถ คำนวณค่า BMI และแสดงเกณฑ์ความอ้วนตามค่าที่คำนวณได้

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🎯 ตัวอย่างผลลัพธ์ของโปรแกรม
#
# ```
# ===== เมนูคำนวณ BMI =====
# 1. เพิ่มข้อมูล BMI
# 2. แสดงรายการ BMI
# 3. ออกจากโปรแกรม
# เลือกเมนู: 1
# ป้อนชื่อ: Alice
# ป้อนน้ำหนัก (kg): 55
# ป้อนส่วนสูง (m): 1.65
# Alice มีค่า BMI: 20.2 (น้ำหนักปกติ)
#
# ===== เมนูคำนวณ BMI =====
# 1. เพิ่มข้อมูล BMI
# 2. แสดงรายการ BMI
# 3. ออกจากโปรแกรม
# เลือกเมนู: 2
#
# ===== รายการ BMI =====
# ชื่อ: Alice, น้ำหนัก: 55 kg, สูง: 1.65 m, BMI: 20.2 (น้ำหนักปกติ)
#
# ```

# %%
#code here

# สร้างตัวแปร List เพื่อเก็บข้อมูล BMI
bmi_records = []

# ฟังก์ชันคำนวณค่า BMI
def calculate_bmi(weight, height):
  return weight / (height ** 2)
