# %% [markdown]
# **Week 1**

# %% [markdown]
# Install Python
# https://www.python.org/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ขณะติดตั้งโปรแกรมอย่าลืมคลิกที่วงกลมสีแดงด้วย

# %% [markdown]
# **Commant prompt**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Basic DOS command**
#
#
#
# ```
# dir # show all files and directories
# cd # change directory
# cd .. # leave current directory
# ```

# %% [markdown]
# **Python Interactive Console**
#
#
# ```
# > python
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ออกจาก Python Interactive Console
#
#
#
# ```
# ctrl + D
# ```

# %% [markdown]
# **Compare basic Python and Java programs**
#
# **Python**
# ```
# gender = 'M'
# name = "Olarik"
# age = 40
#
# print("My name is ", Olarik);
# ```
#
#
# Other Types
# ```
# myNum = 5
# myFloatNum = 5.99
# myLetter = 'D'
# myBool = True
# myText = "Hello"
# ```
#
#
# **Java**
# ```
# char gender = 'M';
# String name = "Olarik";
# int age = 40;
#
# System.out.print("My name is " + Olarik);
# ```
#
#
# Other Types
# ```
# int myNum = 5;
# float myFloatNum = 5.99f;
# char myLetter = 'D';
# boolean myBool = true;
# String myText = "Hello";
# ```

# %% [markdown]
# Sample Code -> **lap1.py**
#
# ใช้โปรแกรม notepad หรือ editplus หรือโปรแกรมอื่น ๆ ในการเขียนโปรแกรม
#
# ** หมายเหตุ ข้อมูลด้านล่างให้ใช้ข้อมูลนิสิต

# %%
#Olarik 67011211060, tel = 095xxxxxxx

name ="Olarik"
surname = "Surinta"
std_id = "67011211060"
tel = "0959xxxxxx"
print("My name is", name, surname)
print(std_id)
print(tel)
print(name+surname)
print(name+" "+surname)
print('*'*20)

a=5
b=6.2
print("a+b=", a+b)

y=2+2*2
print(y)

z=(2+2)*2
print(z)

# %% [markdown]
# **Save Python file**
# นามสกุลคือ "*.py*"
#
# ```
# lap1.py
# ```
#
#
#
# **Compile Python program**
#
#
#
# ```
# > python lap1.py
# ```

# %% [markdown]
# **ส่งงานใน classroom หัวข้อ lap1.py**
#
# ส่งภายในเวลาที่กำหนด
